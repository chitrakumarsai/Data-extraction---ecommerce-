# %%
import sys
import os,os.path
import comtypes.client
import glob
import os
import time
import re
import shutil
from re import search
import win32com.client as win32
import schedule
import datetime as dt
import win32com.client
import os.path
from os import path
def rtfexcel():
    wdFormatPDF = 17
    try:
        pdfs = glob.glob("C:\\Users\\ChitraVenkata\\Dropbox (Cosmic Pet-Business)\\Cosmic - Reporting\\Processes\\Chitra_Working\\Logistics\\Staging\\*.rtf")

        dest = "C:\\Users\\ChitraVenkata\\Dropbox (Cosmic Pet-Business)\\Cosmic - Reporting\\Processes\\Chitra_Working\\Logistics\\Codes\\Logistics\\rtfs\\"
        for pdf_path in pdfs:
            if os.path.getmtime(pdf_path) < time.time() - 14 * 24 * 60 * 60:
                continue
            else:
                shutil.move(pdf_path, dest)

        input_dir = 'C:\\Users\\ChitraVenkata\\Dropbox (Cosmic Pet-Business)\\Cosmic - Reporting\\Processes\\Chitra_Working\\Logistics\\Codes\\Logistics\\rtfs\\'
        output_dir = 'C:\\Users\\ChitraVenkata\\Dropbox (Cosmic Pet-Business)\\Cosmic - Reporting\\Processes\\Chitra_Working\\Logistics\\Staging\\'

        for subdir, dirs, files in os.walk(input_dir):
            for file in files:
                if os.path.getmtime(input_dir+'\\'+ file) < time.time() - 14 * 24 * 60 * 60:
#                     continue
#                 else:
                    in_file = os.path.join(subdir, file)
                print(in_file)
                output_file = file.split('.')[0]
                out_file = output_dir+output_file+'.pdf'
                word = comtypes.client.CreateObject('Word.Application')
                doc = word.Documents.Open(in_file)
                try:
                    doc.SaveAs(out_file, FileFormat=wdFormatPDF)
                except Exception as e:
                    print("Failed to convert")
                    print(str(e))
                finally:
                    doc.Close()
                    word.Quit()
    except:
            print("File not found")



    xls = glob.glob("C:\\Users\\ChitraVenkata\\Dropbox (Cosmic Pet-Business)\\Cosmic - Reporting\\Processes\\Chitra_Working\\Logistics\\Staging\\*.xls")
    for xlsx in xls:
        fname = xlsx
        excel = comtypes.client.CreateObject('Excel.Application')#win32com.client.dynamic.Dispatch('Excel.Application')
        wb = excel.Workbooks.Open(fname)

        wb.SaveAs(fname+"x", FileFormat = 51)    #FileFormat = 51 is for .xlsx extension
        wb.Close()                               #FileFormat = 56 is for .xls extension
        excel.Application.Quit()
        os.remove(xlsx)

    pdfs = glob.glob("C:\\Users\\ChitraVenkata\\Dropbox (Cosmic Pet-Business)\\Cosmic - Reporting\\Processes\\Chitra_Working\\Logistics\\Staging\\*.xlsx")

    dest = "C:\\Users\\ChitraVenkata\\Dropbox (Cosmic Pet-Business)\\Cosmic - Reporting\\Processes\\Chitra_Working\\Logistics\\Codes\\Logistics\\excel"
    for file in pdfs:
        if os.path.getmtime(file) < time.time() - 14 * 24 * 60 * 60:
            continue
        else:
            try:
                shutil.move(file, dest)
            except:
                print("File exists")

    input_dir = 'C:\\Users\\ChitraVenkata\\Dropbox (Cosmic Pet-Business)\\Cosmic - Reporting\\Processes\\Chitra_Working\\Logistics\\Codes\\Logistics\\excel'
    output_dir = 'C:\\Users\\ChitraVenkata\\Dropbox (Cosmic Pet-Business)\\Cosmic - Reporting\\Processes\\Chitra_Working\\Logistics\\Staging\\'

    for subdir, dirs, files in os.walk(input_dir):
        try:
            for file in files:
                if os.path.getmtime(input_dir+'\\'+ file) < time.time() - 14 * 24 * 60 * 60:
                    continue
                else:
                    in_file = os.path.join(subdir, file)
                    output_file = file.split('.')[0]
#                     if output_dir.exists(output_file+'.pdf'):
#                         continue
                    out_file = output_dir+output_file+'.pdf'
                    excel = comtypes.client.CreateObject('Excel.Application')

                    doc = excel.Workbooks.Open(in_file)
                    try:
                        doc.SaveAs(out_file, FileFormat=57)
                    except Exception as e:
                        print("Failed to convert")
                        print(str(e))
                    finally:
                        doc.Close()
                        excel.Quit()
        except:
            print("File not found")

# %%
rtfexcel()
# Out:
# C:\Users\ChitraVenkata\Dropbox (Cosmic Pet-Business)\Cosmic - Reporting\Processes\Chitra_Working\Logistics\Codes\Logistics\rtfs\ci -56 inv.rtf
# C:\Users\ChitraVenkata\Dropbox (Cosmic Pet-Business)\Cosmic - Reporting\Processes\Chitra_Working\Logistics\Codes\Logistics\rtfs\ci -59 inv.rtf
# C:\Users\ChitraVenkata\Dropbox (Cosmic Pet-Business)\Cosmic - Reporting\Processes\Chitra_Working\Logistics\Codes\Logistics\rtfs\ci 51 inv.rtf
# C:\Users\ChitraVenkata\Dropbox (Cosmic Pet-Business)\Cosmic - Reporting\Processes\Chitra_Working\Logistics\Codes\Logistics\rtfs\ci 51 pac.rtf
# C:\Users\ChitraVenkata\Dropbox (Cosmic Pet-Business)\Cosmic - Reporting\Processes\Chitra_Working\Logistics\Codes\Logistics\rtfs\ci 55 inv.rtf
# C:\Users\ChitraVenkata\Dropbox (Cosmic Pet-Business)\Cosmic - Reporting\Processes\Chitra_Working\Logistics\Codes\Logistics\rtfs\ci 55 pac.rtf
# ...

# %%
input_dir = 'C:\\Users\\ChitraVenkata\\Dropbox (Cosmic Pet-Business)\\Cosmic - Reporting\\Processes\\Chitra_Working\\Logistics\\New Documents\\excel\\'
output_dir = 'C:\\Users\\ChitraVenkata\\Dropbox (Cosmic Pet-Business)\\Cosmic - Reporting\\Processes\\Chitra_Working\\Logistics\\New Documents\\'

for subdir, dirs, files in os.walk(input_dir):
    for file in files:
        if os.path.getmtime(input_dir+'\\'+ file) < time.time() - 14 * 24 * 60 * 60:
            print(file)
            continue
        else:
            print(file)

# %%
import os
import glob

files = glob.glob("C:\\Users\\ChitraVenkata\\Dropbox (Cosmic Pet-Business)\\Cosmic - Reporting\\Processes\\Chitra_Working\\Logistics\\Codes\\Logistics\\excel\\*.xlsx")
for f in files:
    os.remove(f)
files = glob.glob("C:\\Users\\ChitraVenkata\\Dropbox (Cosmic Pet-Business)\\Cosmic - Reporting\\Processes\\Chitra_Working\\Logistics\\Codes\\Logistics\\excel\\*.rtf")
for f in files:
    os.remove(f)
files = glob.glob("C:\\Users\\ChitraVenkata\\Dropbox (Cosmic Pet-Business)\\Cosmic - Reporting\\Processes\\Chitra_Working\\Logistics\\Staging\\*.rtf")
for f in files:
    os.remove(f)
