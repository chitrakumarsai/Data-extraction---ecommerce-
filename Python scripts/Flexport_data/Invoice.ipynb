# %%
import requests, json, itertools
import pandas as pd
import datetime as dt
from datetime import datetime,timedelta
from threading import Timer
import schedule
import datetime
from datetime import date
import time
api_token = '96e5afd75f647c10a0ea33d1f162422d'
api_url_base = 'https://api.flexport.com/invoices'

headers = {'Content-Type': 'application/json',
           'Authorization': 'Bearer {0}'.format(api_token)}

# %%
def flexport_invoice_item(invoice):
    invoice_info = invoice['data']
    invoice_data = invoice_info['data']
    lst_InvoiceName = []
    lst_invoice_issueDate = []
    lst_total_amount = []
    lst_item_data = []
    lst_item_name = []
    lst_item_slug = []
    lst_itemcategory = []
    lst_money = []
    lst_item_rate_value = []
    lst_item_qualifier = []
    lst_item_quantity_value = []
    lst_item_quantity_qualifier = []
    
    for i in range(len(invoice_data)):
        data = invoice_data[i]
        ID = data['id']
        for i in range(len(data['items'])):
            name = data['name']
            lst_InvoiceName.append(name)
            total_amount = str(data['total']['amount']) +' ' + str(data['total']['currency_code'])
            lst_total_amount.append(total_amount)
            item_data = data['items'][i]
            item_name = item_data['name']
            lst_item_name.append(item_name)
            invoice_issueDate = data['issued_at']
            chop = len(invoice_issueDate.split()[-1]) -10
            end_date = invoice_issueDate[:-chop]
            lst_invoice_issueDate.append(end_date)
            item_slug = item_data['slug']
            lst_item_slug.append(item_slug)
            item_category = item_data['category']
            lst_itemcategory.append(item_category)
            item_money = str(item_data['amount']['amount']) + ' ' + item_data['amount']['currency_code']
            lst_money.append(item_money)
            if item_data['rate'] != None:
                item_rate_value = item_data['rate']['value']
                lst_item_rate_value.append(item_rate_value)
                item_rate_qualifier = item_data['rate']['qualifier']
                lst_item_qualifier.append(item_rate_qualifier)
            else:
                lst_item_rate_value.append(None)
                lst_item_qualifier.append(None)
            if item_data['quantity'] != None:
                item_quantity_value = item_data['quantity']['value']
                lst_item_quantity_value.append(item_quantity_value)
                item_quantity_qualifier = item_data['quantity']['qualifier']
                lst_item_quantity_qualifier.append(item_quantity_qualifier)
            else:
                lst_item_quantity_value.append(None)
                lst_item_quantity_qualifier.append(None)
                
            
    df_invoice = pd.DataFrame(list(zip(lst_InvoiceName,lst_item_name,lst_invoice_issueDate,lst_item_slug,lst_itemcategory,lst_money,lst_item_rate_value,lst_item_quantity_qualifier,lst_item_quantity_value,lst_item_quantity_qualifier,lst_total_amount)),columns=['Invoice Number','Item name','Invoice issue date','Item slug','Item category','Amount','Rate Value','Rate Quantifier', 'Quantity Value','Quantity Qualifier','Total Amount'])
    return(df_invoice)

# %%
def api_script():
    response = requests.get(api_url_base, headers=headers)
    invoice = response.json()
    result = pd.DataFrame()
    data_f = flexport_invoice_item(invoice)
    result = result.append(data_f,ignore_index=True)
    while invoice['data']['next'] is not None:
        print("Next page found, downloading", invoice['data']['next'])
        response = requests.get(invoice['data']['next'],headers=headers)
        invoice = response.json()
        data_f = flexport_invoice_item(invoice)
        result = result.append(data_f,ignore_index=True)
    result.to_excel('result.xlsx', index= False)
    today = date.today()
    print("Today's date:", today)

# %%
schedule.every().day.at("08:30").do(api_script)
#api_script()
# Out:
# Every 1 day at 08:30:00 do api_script() (last run: [never], next run: 2021-03-17 08:30:00)

# %%
while True: 
    schedule.run_pending() 
    time.sleep(1)
# Out:
# Next page found, downloading https://api.flexport.com/invoices?page=2&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=3&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=4&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=5&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=6&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=7&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=8&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=9&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=10&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=11&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=12&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=13&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=14&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=15&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=16&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=17&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=18&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=19&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=20&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=21&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=22&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=23&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=24&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=25&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=26&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=27&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=28&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=29&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=30&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=31&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=32&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=33&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=34&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=35&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=36&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=37&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=38&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=39&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=40&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=41&per=10
# Today's date: 2021-03-17
# Next page found, downloading https://api.flexport.com/invoices?page=2&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=3&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=4&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=5&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=6&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=7&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=8&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=9&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=10&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=11&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=12&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=13&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=14&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=15&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=16&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=17&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=18&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=19&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=20&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=21&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=22&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=23&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=24&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=25&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=26&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=27&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=28&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=29&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=30&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=31&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=32&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=33&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=34&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=35&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=36&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=37&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=38&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=39&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=40&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=41&per=10
# Today's date: 2021-03-18
# Next page found, downloading https://api.flexport.com/invoices?page=2&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=3&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=4&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=5&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=6&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=7&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=8&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=9&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=10&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=11&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=12&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=13&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=14&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=15&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=16&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=17&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=18&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=19&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=20&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=21&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=22&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=23&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=24&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=25&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=26&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=27&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=28&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=29&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=30&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=31&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=32&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=33&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=34&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=35&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=36&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=37&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=38&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=39&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=40&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=41&per=10
# Today's date: 2021-03-19
# Next page found, downloading https://api.flexport.com/invoices?page=2&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=3&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=4&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=5&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=6&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=7&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=8&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=9&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=10&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=11&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=12&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=13&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=14&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=15&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=16&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=17&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=18&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=19&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=20&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=21&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=22&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=23&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=24&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=25&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=26&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=27&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=28&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=29&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=30&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=31&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=32&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=33&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=34&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=35&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=36&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=37&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=38&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=39&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=40&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=41&per=10
# Today's date: 2021-03-20
# Next page found, downloading https://api.flexport.com/invoices?page=2&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=3&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=4&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=5&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=6&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=7&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=8&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=9&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=10&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=11&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=12&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=13&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=14&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=15&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=16&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=17&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=18&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=19&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=20&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=21&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=22&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=23&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=24&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=25&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=26&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=27&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=28&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=29&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=30&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=31&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=32&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=33&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=34&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=35&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=36&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=37&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=38&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=39&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=40&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=41&per=10
# Today's date: 2021-03-21
# Next page found, downloading https://api.flexport.com/invoices?page=2&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=3&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=4&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=5&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=6&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=7&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=8&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=9&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=10&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=11&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=12&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=13&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=14&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=15&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=16&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=17&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=18&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=19&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=20&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=21&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=22&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=23&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=24&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=25&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=26&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=27&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=28&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=29&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=30&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=31&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=32&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=33&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=34&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=35&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=36&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=37&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=38&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=39&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=40&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=41&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=42&per=10
# Today's date: 2021-03-22
# Next page found, downloading https://api.flexport.com/invoices?page=2&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=3&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=4&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=5&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=6&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=7&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=8&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=9&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=10&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=11&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=12&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=13&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=14&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=15&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=16&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=17&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=18&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=19&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=20&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=21&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=22&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=23&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=24&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=25&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=26&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=27&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=28&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=29&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=30&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=31&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=32&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=33&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=34&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=35&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=36&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=37&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=38&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=39&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=40&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=41&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=42&per=10
# Today's date: 2021-03-23
# Next page found, downloading https://api.flexport.com/invoices?page=2&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=3&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=4&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=5&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=6&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=7&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=8&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=9&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=10&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=11&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=12&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=13&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=14&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=15&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=16&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=17&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=18&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=19&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=20&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=21&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=22&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=23&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=24&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=25&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=26&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=27&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=28&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=29&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=30&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=31&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=32&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=33&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=34&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=35&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=36&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=37&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=38&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=39&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=40&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=41&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=42&per=10
# Today's date: 2021-03-24
# Next page found, downloading https://api.flexport.com/invoices?page=2&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=3&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=4&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=5&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=6&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=7&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=8&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=9&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=10&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=11&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=12&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=13&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=14&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=15&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=16&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=17&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=18&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=19&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=20&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=21&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=22&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=23&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=24&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=25&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=26&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=27&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=28&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=29&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=30&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=31&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=32&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=33&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=34&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=35&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=36&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=37&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=38&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=39&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=40&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=41&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=42&per=10
# Today's date: 2021-03-25
# Next page found, downloading https://api.flexport.com/invoices?page=2&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=3&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=4&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=5&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=6&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=7&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=8&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=9&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=10&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=11&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=12&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=13&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=14&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=15&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=16&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=17&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=18&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=19&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=20&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=21&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=22&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=23&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=24&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=25&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=26&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=27&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=28&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=29&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=30&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=31&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=32&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=33&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=34&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=35&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=36&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=37&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=38&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=39&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=40&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=41&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=42&per=10
# Today's date: 2021-03-26
# Next page found, downloading https://api.flexport.com/invoices?page=2&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=3&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=4&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=5&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=6&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=7&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=8&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=9&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=10&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=11&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=12&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=13&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=14&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=15&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=16&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=17&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=18&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=19&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=20&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=21&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=22&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=23&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=24&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=25&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=26&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=27&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=28&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=29&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=30&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=31&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=32&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=33&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=34&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=35&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=36&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=37&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=38&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=39&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=40&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=41&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=42&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=43&per=10
# Today's date: 2021-03-27
# Next page found, downloading https://api.flexport.com/invoices?page=2&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=3&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=4&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=5&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=6&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=7&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=8&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=9&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=10&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=11&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=12&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=13&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=14&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=15&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=16&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=17&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=18&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=19&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=20&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=21&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=22&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=23&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=24&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=25&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=26&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=27&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=28&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=29&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=30&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=31&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=32&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=33&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=34&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=35&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=36&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=37&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=38&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=39&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=40&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=41&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=42&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=43&per=10
# Today's date: 2021-03-28
# Next page found, downloading https://api.flexport.com/invoices?page=2&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=3&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=4&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=5&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=6&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=7&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=8&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=9&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=10&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=11&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=12&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=13&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=14&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=15&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=16&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=17&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=18&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=19&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=20&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=21&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=22&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=23&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=24&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=25&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=26&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=27&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=28&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=29&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=30&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=31&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=32&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=33&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=34&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=35&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=36&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=37&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=38&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=39&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=40&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=41&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=42&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=43&per=10
# Today's date: 2021-03-29
# Next page found, downloading https://api.flexport.com/invoices?page=2&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=3&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=4&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=5&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=6&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=7&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=8&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=9&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=10&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=11&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=12&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=13&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=14&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=15&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=16&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=17&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=18&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=19&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=20&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=21&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=22&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=23&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=24&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=25&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=26&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=27&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=28&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=29&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=30&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=31&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=32&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=33&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=34&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=35&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=36&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=37&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=38&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=39&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=40&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=41&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=42&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=43&per=10
# Today's date: 2021-03-30
# Next page found, downloading https://api.flexport.com/invoices?page=2&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=3&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=4&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=5&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=6&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=7&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=8&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=9&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=10&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=11&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=12&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=13&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=14&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=15&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=16&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=17&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=18&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=19&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=20&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=21&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=22&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=23&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=24&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=25&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=26&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=27&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=28&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=29&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=30&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=31&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=32&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=33&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=34&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=35&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=36&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=37&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=38&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=39&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=40&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=41&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=42&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=43&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=44&per=10
# Today's date: 2021-03-31
# Next page found, downloading https://api.flexport.com/invoices?page=2&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=3&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=4&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=5&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=6&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=7&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=8&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=9&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=10&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=11&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=12&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=13&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=14&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=15&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=16&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=17&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=18&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=19&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=20&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=21&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=22&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=23&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=24&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=25&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=26&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=27&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=28&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=29&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=30&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=31&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=32&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=33&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=34&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=35&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=36&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=37&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=38&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=39&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=40&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=41&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=42&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=43&per=10
# Next page found, downloading https://api.flexport.com/invoices?page=44&per=10
# Today's date: 2021-04-01
